# %% [markdown]
# This notebook documents the calculation of the dark matter impulse differential rate
# $$
# \frac{dR}{dq}(\alpha_n; M_X, m_\phi) = \frac{f_X \rho_X}{M_X} \int dv \ v f(v) \frac{d\sigma}{dq}
# $$ with massless mediator.

# %%
import numpy as np
from scipy.special import erf
from scipy.interpolate import interp2d
from scipy.integrate import quad

import pickle

import matplotlib.pyplot as plt
import matplotlib.cm as cmx
import matplotlib.colors as colors
from mpl_toolkits.mplot3d import Axes3D

# %%
hbarc = 0.2e-13    # GeV cm
c = 3e10           # cm/s

# DM velocity dist params
# in natural units (vesc = 544e5/c, v0 = 220e5/c, ve = 245e5/c)
vesc  = 1.815e-3   # Galactic escape velocity
v0    = 7.34e-4    # v0 parameter from Zurek group paper
ve    = 8.172e-4   # ve parameter from Zurek group paper
vmin  = 1e-6

nvels = 100

rhoDM = 0.3        # Dark matter mass density, GeV/cm^3
N_T   = 3e14       # Number neutrons
alpha_n = 1e-10

sig = 0.17         # Sigma of inloop (momentum resolution)

hbarc = 0.2e-13    # GeV cm
c = 3e10           # cm/s

# %% [markdown]
# ## Calculate the DM velocity distribution $f(v)$
# There are two choices for velocity distribution:
#
# 1. Asymmetric DM nugget:
# https://arxiv.org/pdf/1812.07573.pdf .
# See Eq. (32) and (33) of the paper. Note there is a typo in the sign of the exponential.
# 2. Standard halo model, which is a truncated Maxwell distribution.
#
# We will just use the standard halo model for calculation considering a generic composite DM.

# %%
def f_halo(v):
    """
    DM velocity distribution in the Earth frame
    
    :param v: input velocity (array-like)
    :return: velocity distribtuion (array-like)
    """
    N0 = np.pi**1.5 * v0**3 * ( erf(vesc/v0) - 2/np.sqrt(np.pi) * (vesc/v0) * np.exp(-(vesc/v0)**2))
    
    # v < (vesc - ve)
    f1 = np.exp( - (v+ve)**2 / v0**2 ) * (np.exp(4*v*ve / v0**2) - 1)
    # (vesc - ve) < v < (vesc + ve)
    f2 = np.exp( - (v-ve)**2 / v0**2 ) - np.exp(- vesc**2 / v0**2)

    f = np.zeros_like(v)
    g1 = v < (vesc - ve)
    g2 = np.logical_and( vesc-ve < v, v < vesc + ve)
    
    f[g1] = f1[g1]
    f[g2] = f2[g2]

    return f * np.pi * v * v0**2 / (N0 * ve)

def f_halo_dan(v):
    """
    I think this is the standard halo model but need to double check.
    See Eq. (2) of https://link.aps.org/doi/10.1103/PhysRevD.42.3572
    """
    N0 = np.pi**1.5 * v0**3 * ( erf(vesc/v0) - 2/np.sqrt(np.pi) * (vesc/v0) * np.exp(-(vesc/v0)**2))
    return 4*np.pi*v**2 * np.exp(-v**2 / v0**2) / N0

# %%
# Plot the DM velocity distribution
vels = np.linspace(vmin, vesc + ve, nvels)
vels_shm = np.linspace(vmin, vesc, nvels)

plt.figure()
plt.plot(vels/vesc, f_halo(vels), label='Nugget (Coskuner+\'18)')
plt.plot(vels_shm/vesc, f_halo_dan(vels_shm), label='Standard Halo Model')

plt.title(f'Velocity distribution, integral = {np.trapz(f_halo(vels), vels):.2f}')
plt.legend(frameon=False)
plt.xlabel('Velocity (v/vesc)')
plt.ylabel('f(v)')
plt.show()

# %% [markdown]
# ## Calculate the differential cross section $\frac{d\sigma}{dq}$
#
# Here $q$ is the momemtum transfer of the impulse. Given a coupling $\alpha$, the cross section can be calculated as a Rutherford scattering problem with potential $V(r) = \alpha / r$.

# %% [markdown]
# First let us do some classical mechanics and check the momemtum transfer $q$ as a function of the impact parameter.

# %%
## Plot q vs b

mx = 5e3  # DM mass (GeV)
v1 = v0   # Assume DM has velocity v0 defined above

bvec_cm = np.logspace(np.log10(5e-4), 0, int(1e3))
bvec = bvec_cm / hbarc  # Impact parameter (1 / GeV)

p = mx * v1
E = 0.5* mx * v1**2
alpha = 1e-8

k = alpha * N_T
q = 2*p / np.sqrt(4*E**2 * bvec**2/k**2 + 1)

plt.figure()
plt.plot(bvec_cm*1e4, q)
plt.xlabel('Impact Param (um)')
plt.ylabel('Momentum Trasnfer (Gev)')

anum = k / (E * bvec)

plt.figure()
plt.plot(bvec_cm*1e4, 2*np.arcsin(anum/np.sqrt(4+anum**2)))
plt.xlabel('Impact Param (um)')
plt.ylabel('Scatt Angle (rad)')      
plt.show()

# %%
qq = np.linspace(0.05, 20, 10000)
aa = np.logspace(-11, -4, 30)

qqmat, aamat = np.meshgrid(qq,aa)

vel_list = np.linspace(vmin, vesc, nvels)

# %%
mx = 5e3
for aidx, alpha in enumerate([1.2e-8,]): ##aa):
    print("Working on mass, alpha: ", mx, alpha)
    nX = rhoDM/mx
    
    dRdq = np.zeros(len(qq))
    dRdq_in = np.zeros(len(qq))
    dRdq_mat = np.zeros((len(qq), nvels))
    dRdq_in_mat = np.zeros((len(qq), nvels))
    
    for vidx, vel in enumerate([vmin]): ##vel_list
        p = mx * vel

        ## Cross section outside the sphere
        #### I think this is the line that calculate the cross section
        #sigvals = (N_T*alpha)**2 * 8*np.pi * 1/qq**3 * 1/vel * f_halo(vel)
        sigvals = np.ones_like(qq) * 1/vel * f_halo_dan(vel)
        Ecm = 0.5*mx*vel**2
        k = alpha * N_T  ##/(4*np.pi) 4pi is already in the def of alpha
        bmin = 5e-4/hbarc ## 
        qmax = 2*mx*vel/np.sqrt(4*Ecm**2 * bmin**2/k**2 + 1)
        
        ## account for vmin at a given q
        sigvals[qq > 2*mx*vel] = 0
        dRdq_mat[:,vidx] = sigvals ##* nX * conv_fac 
        #sigvals[qq > qmax] = 0
        dRdq_in_mat[:,vidx] = sigvals ##* nX * conv_fac
# Out:
# Working on mass, alpha:  5000.0 1.2e-08
