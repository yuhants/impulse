# %%
import sys, os
import numpy as np
import matplotlib.pyplot as plt

# %%
outdir = '/home/yt388/microspheres/impulse/yuhan/data/mphi_1e-04/'
file = 'differential_rate_alpha_1.00000e-08_MX_5.00000e+03.npz'

# %%
dsdq = np.load(outdir+file)

# %%
dsdq.files
# Out:
# ['q', 'dsigdq']

# %%
dsigdq = dsdq['dsigdq']
q = dsdq['q']

# %%
plt.plot(q[0], dsigdq)
plt.xlim(0, 1)
# Out:
# (0.0, 1.0)
